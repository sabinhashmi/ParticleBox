# %%
import pandas as pd
data=pd.read_parquet('/home/hashmi/Files/DataFolder/ParticleBoxData/DownstreamData.parquet')

# %%
data.head()
# Out:
#    track_charge  track_chi2PerDoF  track_nLHCbIDs      track_p  track_phi  \
# 0           1.0          0.070137            12.0  4719.268789   0.503917
# 1          -1.0          0.825198            11.0  5968.491193   3.117314
# 2          -1.0          0.415610            12.0  4439.795650   2.678692
# 3           1.0          0.380737            11.0  2672.354020   0.031277
# 4           1.0          0.637376            11.0  2802.582602   0.028834
#
#    track_position_r  track_position_x  track_position_y     track_pt  \
# 0        760.736764         52.086334        758.951538   931.833411
# 1        750.392212       -750.111389         20.527435  1308.485916
# 2        894.860060       -242.735580        861.309448  1041.913541
# 3        592.861337        580.054932        122.559540   962.754168
# 4        943.479884        937.996155        101.575119  1098.949728
#
#    track_tx  track_ty  track_pseudoRapidity  Downstream
# ...

# %%
kaggleData=data.sample(frac=0.05,random_state=57)

# %%
kaggleData.to_csv('/home/hashmi/Files/DataFolder/ParticleBoxData/KaggleData.csv',index=False)
