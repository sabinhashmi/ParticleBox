# %%
import pandas as pd
import uproot

# %%
array=['track_chi2PerDoF', 'track_nLHCbIDs',
       'track_p', 'track_phi', 'track_position_phi', 'track_position_r',
       'track_position_x', 'track_position_y', 'track_position_z', 'track_pt',
       'track_tx', 'track_ty', 'track_pseudoRapidity']

# %%
baseline_ds=uproot.open('/home/hashmi/Files/Trigger/Data/Baseline/DownstreamDumper_runNb_10452279_evtNb_59493.root:Particle_Data')
baseline_ds=baseline_ds.arrays(array,library='pd')
baseline_gs=uproot.open('/home/hashmi/Files/Trigger/Data/Baseline/GhostDumper_runNb_10452279_evtNb_59493.root:Particle_Data')
baseline_gs=baseline_gs.arrays(array,library='pd')


classifier_ds=uproot.open('/home/hashmi/Files/Trigger/Data/Classifier/DownstreamDumper_runNb_10452279_evtNb_59493.root:Particle_Data')
classifier_ds=classifier_ds.arrays(array,library='pd')
classifier_gs=uproot.open('/home/hashmi/Files/Trigger/Data/Classifier/GhostDumper_runNb_10452279_evtNb_59493.root:Particle_Data')
classifier_gs=classifier_gs.arrays(array,library='pd')

# %%
baseline_ds.head()
# Out:
#    track_chi2PerDoF  track_nLHCbIDs      track_p  track_phi  \
# 0               0.0            12.0  6238.681001   2.904447
# 1               0.0            12.0  6781.995356   3.120946
# 2               0.0            12.0  5668.715713   2.774161
# 3               0.0            11.0  5051.751199   3.000551
# 4               0.0            12.0  6401.646847   2.890559
#
#    track_position_phi  track_position_r  track_position_x  track_position_y  \
# 0            2.683804       1089.638496       -977.440674        481.582581
# 1            3.096467        899.452936       -898.537292         40.574844
# 2            2.399458       1182.166599       -871.289307        798.982361
# 3            2.793135        862.858882       -811.001343        294.622253
# 4            2.604756        849.249706       -729.786316        434.323608
#
#    track_position_z     track_pt  track_tx  track_ty  track_pseudoRapidity
# ...

# %%
classifier_ds.head()
# Out:
#    track_chi2PerDoF  track_nLHCbIDs      track_p  track_phi  \
# 0               0.0            12.0  6238.681001   2.904447
# 1               0.0            12.0  6781.995356   3.120946
# 2               0.0            12.0  5668.715713   2.774161
# 3               0.0            11.0  5051.751199   3.000551
# 4               0.0            12.0  6401.646847   2.890559
#
#    track_position_phi  track_position_r  track_position_x  track_position_y  \
# 0            2.683804       1089.638496       -977.440674        481.582581
# 1            3.096467        899.452936       -898.537292         40.574844
# 2            2.399458       1182.166599       -871.289307        798.982361
# 3            2.793135        862.858882       -811.001343        294.622253
# 4            2.604756        849.249706       -729.786316        434.323608
#
#    track_position_z     track_pt  track_tx  track_ty  track_pseudoRapidity
# ...
