# %%
import Model.GhostClassifier as model
import pandas as pd
import numpy as np
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_parquet('/home/hashmi/Files/DataFolder/ParticleBoxData/DownstreamData.parquet')

# %%
sample=data.sample(frac=0.0001)
x=sample.drop('Downstream',axis=1)
y=sample['Downstream']

# %%
sample.head()
# Out:
#          track_chi2PerDoF  track_nLHCbIDs       track_p  track_phi  \
# 4748131          0.341014            12.0   6473.890178   0.044551
# 5542135          0.364621            10.0  20316.601324  -2.204953
# 25714            1.919460            12.0   4816.519944   2.920155
# 8629798          1.147321            10.0   2156.449626   3.057730
# 2978758          0.958761             9.0   3521.684597  -2.942324
#
#          track_position_phi  track_position_r  track_position_x  \
# 4748131            0.118512        671.349576        666.640503
# 5542135           -1.846321        827.490549       -225.120651
# 25714              2.563960        602.906380       -505.089355
# 8629798            2.741159       1258.208494      -1158.674072
# 2978758           -1.687724        334.047580        -38.970604
#
#          track_position_y     track_pt  track_tx  track_ty  \
# 4748131         79.376907  1337.326292  0.210917  0.009403
# 5542135       -796.279663  2341.827656 -0.068754 -0.093479
# 25714          329.212463  1095.428807 -0.227849  0.051296
# 8629798        490.472229  1084.501374 -0.579800  0.048738
# 2978758       -331.766602   794.710330 -0.227053 -0.045853
#
#          track_pseudoRapidity  Downstream
# 4748131              2.259409        True
# 5542135              2.850316       False
# 25714                2.160863       False
# 8629798              1.310249       False
# 2978758              2.168883       False

# %%
#Probability= e^logit/1+e^logit
probabilityOut=[]
for x_row in tqdm(x.iterrows()):
    rawOut=model.apply_catboost_model(x_row[1])
    probabilityOut.append(np.exp(rawOut)/(1+np.exp(rawOut)))
# Out:
# 998it [00:02, 429.86it/s]

# %%
sample['Probability']=probabilityOut
sample.head()
# Out:
#          track_chi2PerDoF  track_nLHCbIDs       track_p  track_phi  \
# 4748131          0.341014            12.0   6473.890178   0.044551
# 5542135          0.364621            10.0  20316.601324  -2.204953
# 25714            1.919460            12.0   4816.519944   2.920155
# 8629798          1.147321            10.0   2156.449626   3.057730
# 2978758          0.958761             9.0   3521.684597  -2.942324
#
#          track_position_phi  track_position_r  track_position_x  \
# 4748131            0.118512        671.349576        666.640503
# 5542135           -1.846321        827.490549       -225.120651
# 25714              2.563960        602.906380       -505.089355
# 8629798            2.741159       1258.208494      -1158.674072
# 2978758           -1.687724        334.047580        -38.970604
#
#          track_position_y     track_pt  track_tx  track_ty  \
# 4748131         79.376907  1337.326292  0.210917  0.009403
# 5542135       -796.279663  2341.827656 -0.068754 -0.093479
# 25714          329.212463  1095.428807 -0.227849  0.051296
# 8629798        490.472229  1084.501374 -0.579800  0.048738
# 2978758       -331.766602   794.710330 -0.227053 -0.045853
#
#          track_pseudoRapidity  Downstream  Probability
# 4748131              2.259409        True     0.664449
# 5542135              2.850316       False     0.040185
# 25714                2.160863       False     0.584002
# 8629798              1.310249       False     0.731277
# 2978758              2.168883       False     0.024455

# %%
plt.figure(figsize=(12,8))
figure=sns.histplot(data=sample,x='Probability',hue='Downstream',stat='density',bins=100,palette='dark')
plt.xlabel('Probability Value')
plt.ylabel('')
plt.legend(labels=['Ghost Track','True Track'])
# plt.savefig('./Plots/ClassifierPlots/Train_Distribution.eps')
plt.show()
