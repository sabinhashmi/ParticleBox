# %%
import ROOT

#open
Data=ROOT.TFile('./clustered_data.root')
tree=Data.Particle_Data
# Out:
# Welcome to JupyROOT 6.22/02

# %%
# %jsroot on
c2=ROOT.TCanvas()
tree.SetLineColor(1)
tree.Draw('track_position_x','Ghost==0')
tree.SetLineColor(2)
tree.Draw('track_position_x','Ghost==1','SAME')

tree.SetLineColor(3)
tree.Draw('track_position_x','particle_isDown_noVelo==1','SAME')

tree.SetLineColor(4)
tree.Draw('track_position_x','label==0','SAME')

tree.SetLineColor(4)
tree.Draw('track_position_x','label==1','SAME')

tree.SetLineColor(4)
tree.Draw('track_position_x','label==2','SAME')
c2.Draw()
# Out:
# <div id="root_plot_1646724276292"
#      style="width: 696px; height: 472px">
# </div>
# <script src="/static/components/requirejs/require.js" type="text/javascript" charset="utf-8"></script>
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : '/static/scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
import ROOT

#open
Data=ROOT.TFile('./clustered_data.root')
tree=Data.Particle_Data
